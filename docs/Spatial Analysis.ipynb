# %% [markdown]
# # Error In Spatial Analysis
# ### Branson Fox
# The objective of this notebook is to test the variability in results of fitting spatial models based on using various geocoding options. We will first analyze and fit models using the groud truth, and then fit the same models using all 14 of the tested geocoders.

# %% [markdown]
# ## Dependencies
# The modules are used to produce this analysis. Note that we are using PySal 2.2.

# %%
import os
import numpy as np
import pysal as ps

# %% [markdown]
# ## Load Data
# We'll define a list of geocoders and load the data appropriately. Then we'll set the model parameters (which are the same throughout datasets)

# %%
# Load Data
geocoders = ['truth', 'BingSingle', 'EsriSingle', 'Google', 'HereSingle', 'OpenCage', 'TomTomSingle', 'CensusSingle', 'GeocodioSingle', 'TomTomBatch', 'BingBatch', 'CensusBatch', 'GeocodioBatch', 'EsriBatch', 'HereBatch']
datasets = {}
for geocoder in geocoders:
    datasets[geocoder] = {'data' : ps.lib.io.open('../data/shapes/' + geocoder + '.dbf')}
    
# Set Parameters
shape = ps.lib.io.open('../data/shapes/truth.shp')
weights = ps.lib.weights.Queen(shape)

# Variables
dependent = 'homicides'
independent = ['med_inc', 'homeown', 'non_wht', 'poverty']

# %% [markdown]
# We need the data to be in arrays to work with PySal, so we'll pre-format those.

# %%
# Create Arrays of Data for Each Geocoder
for dataset in datasets:
    datasets[dataset]['y'] = np.array([datasets[dataset]['data'].by_col(dependent)]).T
    datasets[dataset]['x'] = np.array([datasets[dataset]['data'].by_col(var) for var in independent]).T

# %% [markdown]
# ## Explore The Ground Truth
# We'll determine the appropriate spatial model to fit using the ground truth as our basis

# %%
truth_ols = ps.model.spreg.OLS(datasets['truth']['y'], datasets['truth']['x'],
                               w=weights, name_y=dependent, name_x=independent,
                               spat_diag=True, moran=True, name_w='Queens', name_ds='Ground Truth')
print(truth_ols.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :Ground Truth
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      6.3697                Number of Variables   :           5
# S.D. dependent var  :      7.6801                Degrees of Freedom    :         233
# R-squared           :      0.5700
# Adjusted R-squared  :      0.5627
# Sum squared residual:    6010.386                F-statistic           :     77.2297
# Sigma-square        :      25.796                Prob(F-statistic)     :   1.325e-41
# S.E. of regression  :       5.079                Log likelihood        :    -721.955
# Sigma-square ML     :      25.254                Akaike info criterion :    1453.910
# S.E of regression ML:      5.0253                Schwarz criterion     :    1471.272
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT     -11.0885355       1.7792481      -6.2321471       0.0000000
#              med_inc       0.0002057       0.0000272       7.5596853       0.0000000
#              homeown       5.8967441       2.4483016       2.4085039       0.0167957
#              non_wht      24.4278514       1.8963295      12.8816495       0.0000000
#              poverty     -11.4399862       4.9381356      -2.3166610       0.0213906
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           13.910
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2          54.415           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                4          56.086           0.0000
# Koenker-Bassett test              4          32.255           0.0000
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)              0.4634        12.446           0.0000
# Lagrange Multiplier (lag)         1         172.167           0.0000
# Robust LM (lag)                   1          40.202           0.0000
# Lagrange Multiplier (error)       1         135.078           0.0000
# Robust LM (error)                 1           3.113           0.0777
# Lagrange Multiplier (SARMA)       2         175.280           0.0000
#
# ================================ END OF REPORT =====================================

# %% [markdown]
# Based on this OLS Model, it will be appropriate to fit a spatial lag model. We'll do that for the ground truth, and then for each of the additional geocoders.

# %%
truth_lag = ps.model.spreg.GM_Lag(datasets['truth']['y'], datasets['truth']['x'],
                               w=weights, name_y=dependent, name_x=independent,
                               name_w='Queens', name_ds='Ground Truth')
print(truth_lag.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :Ground Truth
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      6.3697                Number of Variables   :           6
# S.D. dependent var  :      7.6801                Degrees of Freedom    :         232
# Pseudo R-squared    :      0.8142
# Spatial Pseudo R-squared:  0.6299
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -4.0759764       1.4015459      -2.9082005       0.0036352
#              med_inc       0.0000732       0.0000231       3.1646632       0.0015526
#              homeown       1.7169311       1.6687826       1.0288525       0.3035490
#              non_wht       7.5036368       2.2538880       3.3291968       0.0008710
#              poverty      -3.4967871       3.3511972      -1.0434441       0.2967426
#          W_homicides       0.1355268       0.0150642       8.9966304       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================

# %% [markdown]
# ## Fit 14 Additional Models

# %%
for geocoder in geocoders[1:]:
    lag = ps.model.spreg.GM_Lag(datasets[geocoder]['y'], datasets[geocoder]['x'],
                               w=weights, name_y=dependent, name_x=independent,
                               name_w='Queens', name_ds=geocoder)
    print(lag.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :  BingSingle
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      6.2815                Number of Variables   :           6
# S.D. dependent var  :      7.6097                Degrees of Freedom    :         232
# Pseudo R-squared    :      0.8126
# Spatial Pseudo R-squared:  0.6282
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -4.1397177       1.4003068      -2.9562933       0.0031136
#              med_inc       0.0000730       0.0000230       3.1770927       0.0014876
#              homeown       1.8970813       1.6668684       1.1381110       0.2550741
#              non_wht       7.9562424       2.2522815       3.5325258       0.0004116
#              poverty      -4.2815226       3.3397158      -1.2820021       0.1998419
#          W_homicides       0.1332338       0.0152391       8.7429171       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :  EsriSingle
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      6.3613                Number of Variables   :           6
# S.D. dependent var  :      7.6769                Degrees of Freedom    :         232
# Pseudo R-squared    :      0.8121
# Spatial Pseudo R-squared:  0.6311
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -4.1687947       1.4087895      -2.9591323       0.0030851
#              med_inc       0.0000753       0.0000232       3.2407602       0.0011921
#              homeown       1.7542597       1.6775090       1.0457527       0.2956752
#              non_wht       7.6221273       2.2611039       3.3709762       0.0007490
#              poverty      -3.4752555       3.3666030      -1.0322736       0.3019439
#          W_homicides       0.1344721       0.0151204       8.8934001       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :      Google
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      6.3571                Number of Variables   :           6
# S.D. dependent var  :      7.6628                Degrees of Freedom    :         232
# Pseudo R-squared    :      0.8129
# Spatial Pseudo R-squared:  0.6279
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -3.9942580       1.3853847      -2.8831399       0.0039373
#              med_inc       0.0000734       0.0000230       3.1960847       0.0013931
#              homeown       1.6116819       1.6607273       0.9704675       0.3318135
#              non_wht       7.7435688       2.2571165       3.4307351       0.0006019
#              poverty      -4.0689508       3.3701324      -1.2073564       0.2272949
#          W_homicides       0.1346700       0.0150309       8.9595309       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            
0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :   BingBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      6.2899                Number of Variables   :           6
# S.D. dependent var  :      7.6331                Degrees of Freedom    :         232
# Pseudo R-squared    :      0.8183
# Spatial Pseudo R-squared:  0.6361
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -4.3121517       1.3950196      -3.0911047       0.0019941
#              med_inc       0.0000743       0.0000228       3.2582562       0.0011210
#              homeown       2.0356635       1.6530044       1.2314931       0.2181385
#              non_wht       7.8052166       2.2156228       3.5228092       0.0004270
#              poverty      -3.6606940       3.2867952      -1.1137579       0.2653831
#          W_homicides       0.1335543       0.0149433       8.9374307       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            : CensusBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      5.1681                Number of Variables   :           6
# S.D. dependent var  :      6.1751                Degrees of Freedom    :         232
# Pseudo R-squared    :      0.8251
# Spatial Pseudo R-squared:  0.6450
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -3.5921780       1.1337490      -3.1684067       0.0015328
#              med_inc       0.0000606       0.0000182       3.3277966       0.0008754
#              homeown       1.8541599       1.3420011       1.3816381       0.1670828
#              non_wht       5.7773911       1.7429349       3.3147486       0.0009173
#              poverty      -2.0927571       2.5914366      -0.8075664       0.4193402
#          W_homicides       0.1369663       0.0145330       9.4245137       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :GeocodioBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      6.3193                Number of Variables   :           6
# S.D. dependent var  :      7.4836                Degrees of Freedom    :         232
# Pseudo R-squared    :      0.8140
# Spatial Pseudo R-squared:  0.6143
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -3.4413218       1.3168602      -2.6132781       0.0089678
#              med_inc       0.0000706       0.0000224       3.1508404       0.0016280
#              homeown       0.9280508       1.5958519       0.5815394       0.5608770
#              non_wht       7.3437346       2.2179404       3.3110604       0.0009294
#              poverty      -4.2850175       3.3080423      -1.2953334       0.1952053
#          W_homicides       0.1367423       0.0151050       9.0528009       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :   EsriBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      6.3613                Number of Variables   :           6
# S.D. dependent var  :      7.6769                Degrees of Freedom    :         232
# Pseudo R-squared    :      0.8121
# Spatial Pseudo R-squared:  0.6311
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -4.1687947       1.4087895      -2.9591323       0.0030851
#              med_inc       0.0000753       0.0000232       3.2407602       0.0011921
#              homeown       1.7542597       1.6775090       1.0457527       0.2956752
#              non_wht       7.6221273       2.2611039       3.3709762       0.0007490
#              poverty      -3.4752555       3.3666030      -1.0322736       0.3019439
#          W_homicides       0.1344721       0.0151204       8.8934001       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :   HereBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         238
# Mean dependent var  :      6.3487                Number of Variables   :           6
# S.D. dependent var  :      7.6644                Degrees of Freedom    :         232
# Pseudo R-squared    :      0.8093
# Spatial Pseudo R-squared:  0.6256
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -4.0586536       1.4004906      -2.8980227       0.0037552
#              med_inc       0.0000744       0.0000231       3.2188650       0.0012870
#              homeown       1.6607027       1.6806144       0.9881521       0.3230782
#              non_wht       7.7877489       2.2880644       3.4036406       0.0006649
#              poverty      -3.9906459       3.4094610      -1.1704624       0.2418149
#          W_homicides       0.1340997       0.0152345       8.8023905       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================

# %% [markdown]
# Notes: Poverty becomes significant in the OpenCage Model
