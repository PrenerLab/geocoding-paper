# %% [markdown]
# # Error In Spatial Analysis
# ### Branson Fox
# The objective of this notebook is to test the variability in results of fitting spatial models based on using various geocoding options. We will first analyze and fit models using the groud truth, and then fit the same models using all 14 of the tested geocoders.

# %% [markdown]
# ## Dependencies
# The modules are used to produce this analysis. Note that we are using PySal 2.2.

# %%
import os
import numpy as np
import pysal as ps

# %% [markdown]
# ## Load Data
# We'll define a list of geocoders and load the data appropriately. Then we'll set the model parameters (which are the same throughout datasets)

# %%
# Load Data
geocoders = ['truth', 'BingSingle', 'EsriSingle', 'Google', 'HereSingle', 'OpenCage', 'TomTomSingle', 'CensusSingle', 'GeocodioSingle', 'TomTomBatch', 'BingBatch', 'CensusBatch', 'GeocodioBatch', 'EsriBatch', 'HereBatch']
datasets = {}
for geocoder in geocoders:
    datasets[geocoder] = {'data' : ps.lib.io.open('../data/shapes/' + geocoder + '.dbf')}
    
# Set Parameters
shape = ps.lib.io.open('../data/shapes/truth.shp')
weights = ps.lib.weights.Queen(shape)

# Variables
dependent = 'homicides'
independent = ['med_inc', 'homeown', 'non_wht', 'poverty']

# %% [markdown]
# We need the data to be in arrays to work with PySal, so we'll pre-format those.

# %%
# Create Arrays of Data for Each Geocoder
for dataset in datasets:
    datasets[dataset]['y'] = np.array([datasets[dataset]['data'].by_col(dependent)]).T
    datasets[dataset]['x'] = np.array([datasets[dataset]['data'].by_col(var) for var in independent]).T

# %% [markdown]
# ## Explore The Ground Truth
# We'll determine the appropriate spatial model to fit using the ground truth as our basis

# %%
truth_ols = ps.model.spreg.OLS(datasets['truth']['y'], datasets['truth']['x'],
                               w=weights, name_y=dependent, name_x=independent,
                               spat_diag=True, moran=True, name_w='Queens', name_ds='Ground Truth')
print(truth_ols.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :Ground Truth
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7933                Number of Variables   :           5
# S.D. dependent var  :      4.3930                Degrees of Freedom    :         242
# R-squared           :      0.4693
# Adjusted R-squared  :      0.4605
# Sum squared residual:    2519.385                F-statistic           :     53.5011
# Sigma-square        :      10.411                Prob(F-statistic)     :   2.939e-32
# S.E. of regression  :       3.227                Log likelihood        :    -637.292
# Sigma-square ML     :      10.200                Akaike info criterion :    1284.584
# S.E of regression ML:      3.1937                Schwarz criterion     :    1302.131
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -6.5820307       1.1092438      -5.9338000       0.0000000
#              med_inc       0.0001147       0.0000167       6.8853676       0.0000000
#              homeown       3.4514827       1.5256027       2.2623732       0.0245618
#              non_wht      12.2680195       1.1573999      10.5996377       0.0000000
#              poverty      -5.0660450       3.0219019      -1.6764426       0.0949429
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           13.924
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2         377.086           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                4         144.002           0.0000
# Koenker-Bassett test              4          40.513           0.0000
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)              0.4938        13.358           0.0000
# Lagrange Multiplier (lag)         1         205.802           0.0000
# Robust LM (lag)                   1          49.469           0.0000
# Lagrange Multiplier (error)       1         157.056           0.0000
# Robust LM (error)                 1           0.723           0.3951
# Lagrange Multiplier (SARMA)       2         206.525           0.0000
#
# ================================ END OF REPORT =====================================

# %% [markdown]
# Based on this OLS Model, it will be appropriate to fit a spatial lag model. We'll do that for the ground truth, and then for each of the additional geocoders.

# %%
truth_lag = ps.model.spreg.GM_Lag(datasets['truth']['y'], datasets['truth']['x'],
                               w=weights, name_y=dependent, name_x=independent,
                               name_w='Queens', name_ds='Ground Truth')
print(truth_lag.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :Ground Truth
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7933                Number of Variables   :           6
# S.D. dependent var  :      4.3930                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7988
# Spatial Pseudo R-squared:  0.5697
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.8920716       0.8134011      -2.3261238       0.0200119
#              med_inc       0.0000349       0.0000127       2.7394890       0.0061535
#              homeown       0.9964329       0.9622978       1.0354725       0.3004483
#              non_wht       2.0930241       1.2034912       1.7391271       0.0820124
#              poverty      -0.7513853       1.8939979      -0.3967192       0.6915745
#          W_homicides       0.1590049       0.0152085      10.4549795       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================

# %% [markdown]
# ## Fit 14 Additional Models

# %%
for geocoder in geocoders[1:]:
    lag = ps.model.spreg.GM_Lag(datasets[geocoder]['y'], datasets[geocoder]['x'],
                               w=weights, name_y=dependent, name_x=independent,
                               name_w='Queens', name_ds=geocoder)
    print(lag.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :  BingSingle
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7508                Number of Variables   :           6
# S.D. dependent var  :      4.3441                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7950
# Spatial Pseudo R-squared:  0.5707
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.8878998       0.8117071      -2.3258387       0.0200272
#              med_inc       0.0000343       0.0000127       2.7037463       0.0068563
#              homeown       1.0396959       0.9605874       1.0823543       0.2790951
#              non_wht       2.2048949       1.2036642       1.8318190       0.0669784
#              poverty      -1.0049242       1.8919056      -0.5311704       0.5953007
#          W_homicides       0.1581693       0.0154116      10.2629943       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :  EsriSingle
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7867                Number of Variables   :           6
# S.D. dependent var  :      4.3843                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7962
# Spatial Pseudo R-squared:  0.5721
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.9294547       0.8162719      -2.3637403       0.0180915
#              med_inc       0.0000358       0.0000128       2.7941916       0.0052030
#              homeown       1.0077707       0.9661145       1.0431173       0.2968940
#              non_wht       2.1736501       1.2067495       1.8012438       0.0716645
#              poverty      -0.7973608       1.9020717      -0.4192065       0.6750652
#          W_homicides       0.1578770       0.0152903      10.3253037       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :      Google
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7826                Number of Variables   :           6
# S.D. dependent var  :      4.3549                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7989
# Spatial Pseudo R-squared:  0.5693
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.8437997       0.7996647      -2.3057160       0.0211265
#              med_inc       0.0000344       0.0000126       2.7356981       0.0062248
#              homeown       0.9481251       0.9505942       0.9974025       0.3185692
#              non_wht       2.0940065       1.1924493       1.7560550       0.0790790
#              poverty      -0.8321206       1.8811582      -0.4423448       0.6582397
#          W_homicides       0.1590983       0.0150909      10.5426352       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :  HereSingle
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7724                Number of Variables   :           6
# S.D. dependent var  :      4.3484                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7951
# Spatial Pseudo R-squared:  0.5698
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.8708904       0.8083901      -2.3143411       0.0206490
#              med_inc       0.0000350       0.0000126       2.7662221       0.0056710
#              homeown       0.9677128       0.9603560       1.0076605       0.3136175
#              non_wht       2.1746034       1.2042748       1.8057368       0.0709595
#              poverty      -0.9161591       1.8961675      -0.4831636       0.6289796
#          W_homicides       0.1581193       0.0152937      10.3388463       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :    OpenCage
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.6419                Number of Variables   :           6
# S.D. dependent var  :      4.0744                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7732
# Spatial Pseudo R-squared:  0.5181
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.3778606       0.7529693      -1.8299026       0.0672645
#              med_inc       0.0000316       0.0000124       2.5471191       0.0108616
#              homeown       0.4792725       0.9250126       0.5181254       0.6043708
#              non_wht       2.2482625       1.2098936       1.8582316       0.0631361
#              poverty      -1.9623570       1.9133876      -1.0255930       0.3050835
#          W_homicides       0.1588949       0.0162253       9.7930415       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :TomTomSingle
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7583                Number of Variables   :           6
# S.D. dependent var  :      4.2945                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.8017
# Spatial Pseudo R-squared:  0.5622
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.8739034       0.7887290      -2.3758519       0.0175085
#              med_inc       0.0000341       0.0000125       2.7341400       0.0062543
#              homeown       1.0111452       0.9332852       1.0834257       0.2786195
#              non_wht       2.0620019       1.1641219       1.7712938       0.0765119
#              poverty      -0.7289036       1.8353283      -0.3971516       0.6912557
#          W_homicides       0.1589540       0.0152388      10.4308816       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :CensusSingle
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7217                Number of Variables   :           6
# S.D. dependent var  :      4.2397                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.8074
# Spatial Pseudo R-squared:  0.5740
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.8070239       0.7694443      -2.3484792       0.0188503
#              med_inc       0.0000335       0.0000120       2.7857083       0.0053411
#              homeown       0.9647176       0.9103252       1.0597506       0.2892581
#              non_wht       2.0420787       1.1316732       1.8044775       0.0711565
#              poverty      -0.8523267       1.7854453      -0.4773749       0.6330952
#          W_homicides       0.1592809       0.0147873      10.7714771       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :GeocodioSingle
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7409                Number of Variables   :           6
# S.D. dependent var  :      4.2556                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7985
# Spatial Pseudo R-squared:  0.5599
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.7750877       0.7790219      -2.2786109       0.0226902
#              med_inc       0.0000343       0.0000123       2.7817131       0.0054073
#              homeown       0.8615899       0.9270030       0.9294359       0.3526632
#              non_wht       2.0929732       1.1682979       1.7914722       0.0732176
#              poverty      -0.9195227       1.8398735      -0.4997749       0.6172336
#          W_homicides       0.1587030       0.0152230      10.4252021       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            : TomTomBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7583                Number of Variables   :           6
# S.D. dependent var  :      4.2945                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.8017
# Spatial Pseudo R-squared:  0.5622
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.8739034       0.7887290      -2.3758519       0.0175085
#              med_inc       0.0000341       0.0000125       2.7341400       0.0062543
#              homeown       1.0111452       0.9332852       1.0834257       0.2786195
#              non_wht       2.0620019       1.1641219       1.7712938       0.0765119
#              poverty      -0.7289036       1.8353283      -0.3971516       0.6912557
#          W_homicides       0.1589540       0.0152388      10.4308816       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :   BingBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7632                Number of Variables   :           6
# S.D. dependent var  :      4.3752                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7983
# Spatial Pseudo R-squared:  0.5765
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.9457572       0.8143132      -2.3894457       0.0168738
#              med_inc       0.0000350       0.0000127       2.7497709       0.0059637
#              homeown       1.0732170       0.9609801       1.1167942       0.2640823
#              non_wht       2.1825812       1.1980207       1.8218226       0.0684819
#              poverty      -0.8274412       1.8866025      -0.4385880       0.6609601
#          W_homicides       0.1579664       0.0152579      10.3530912       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            : CensusBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.2589                Number of Variables   :           6
# S.D. dependent var  :      3.5090                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.8028
# Spatial Pseudo R-squared:  0.5578
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.5386513       0.6546536      -2.3503290       0.0187568
#              med_inc       0.0000283       0.0000101       2.8047165       0.0050361
#              homeown       0.8467852       0.7724701       1.0962046       0.2729893
#              non_wht       1.5883877       0.9557091       1.6619990       0.0965130
#              poverty      -0.4999213       1.4958122      -0.3342140       0.7382181
#          W_homicides       0.1605731       0.0151340      10.6100610       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :GeocodioBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7409                Number of Variables   :           6
# S.D. dependent var  :      4.2556                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7985
# Spatial Pseudo R-squared:  0.5599
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.7750877       0.7790219      -2.2786109       0.0226902
#              med_inc       0.0000343       0.0000123       2.7817131       0.0054073
#              homeown       0.8615899       0.9270030       0.9294359       0.3526632
#              non_wht       2.0929732       1.1682979       1.7914722       0.0732176
#              poverty      -0.9195227       1.8398735      -0.4997749       0.6172336
#          W_homicides       0.1587030       0.0152230      10.4252021       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :   EsriBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7867                Number of Variables   :           6
# S.D. dependent var  :      4.3843                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7962
# Spatial Pseudo R-squared:  0.5721
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.9294547       0.8162719      -2.3637403       0.0180915
#              med_inc       0.0000358       0.0000128       2.7941916       0.0052030
#              homeown       1.0077707       0.9661145       1.0431173       0.2968940
#              non_wht       2.1736501       1.2067495       1.8012438       0.0716645
#              poverty      -0.7973608       1.9020717      -0.4192065       0.6750652
#          W_homicides       0.1578770       0.0152903      10.3253037       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :   HereBatch
# Weights matrix      :      Queens
# Dependent Variable  :   homicides                Number of Observations:         247
# Mean dependent var  :      2.7724                Number of Variables   :           6
# S.D. dependent var  :      4.3484                Degrees of Freedom    :         241
# Pseudo R-squared    :      0.7951
# Spatial Pseudo R-squared:  0.5698
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -1.8708904       0.8083901      -2.3143411       0.0206490
#              med_inc       0.0000350       0.0000126       2.7662221       0.0056710
#              homeown       0.9677128       0.9603560       1.0076605       0.3136175
#              non_wht       2.1746034       1.2042748       1.8057368       0.0709595
#              poverty      -0.9161591       1.8961675      -0.4831636       0.6289796
#          W_homicides       0.1581193       0.0152937      10.3388463       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_homicides
# Instruments: W_homeown, W_med_inc, W_non_wht, W_poverty
# ================================ END OF REPORT =====================================

# %% [markdown]
# Notes: Needs to Be Re-Analyzed with the modification of homicides to a rate.
